# %% [markdown]
# ## Links:
#
# https://www.kaggle.com/c/web-traffic-time-series-forecasting/rules
#
# https://github.com/Arturus/kaggle-web-traffic
#
# https://www.kaggle.com/headsortails/wiki-traffic-forecast-exploration-wtf-eda

# %%
#downloading the data of web traffic for approximately 145,000 Wikipedia articles
# !kaggle competitions download web-traffic-time-series-forecasting
# Out:
# ...
# 100%|██████████████████████████████████████| 66.0M/66.0M [00:21<00:00, 3.60MB/s]
#
# ...
# 100%|██████████████████████████████████████| 96.0M/96.0M [00:31<00:00, 3.58MB/s]
#
# ...
# 100%|████████████████████████████████████████| 102M/102M [00:40<00:00, 3.09MB/s]
#
# ...
# 100%|█████████████████████████████████████▉| 68.0M/68.2M [00:20<00:00, 3.61MB/s]
# 100%|██████████████████████████████████████| 68.2M/68.2M [00:20<00:00, 3.56MB/s]
# ...
# 100%|████████████████████████████████████████| 101M/101M [00:30<00:00, 3.65MB/s]
#
# ...
# 100%|███████████████████████████████████████▉| 150M/150M [00:44<00:00, 3.62MB/s]
# 100%|████████████████████████████████████████| 150M/150M [00:44<00:00, 3.56MB/s]

# %%
#unzipping the train_1 data
import zipfile
zip_ref = zipfile.ZipFile('train_1.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()

#unzipping the train_2 data
zip_ref = zipfile.ZipFile('train_2.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()

#unzipping the key_1 data
zip_ref = zipfile.ZipFile('key_1.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()

#unzipping the key_2 data
zip_ref = zipfile.ZipFile('key_2.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()

#unzipping the sample_submission_1 data
zip_ref = zipfile.ZipFile('sample_submission_1.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()

#unzipping the sample_submission_2 data
zip_ref = zipfile.ZipFile('sample_submission_2.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd

#Each of these time series represent a number of daily views of a different Wikipedia article, starting from 
#July, 1st, 2015 up until December 31st, 2016.
train_1 = pd.read_csv('train_1.csv')
print(train_1.columns[1])
print(train_1.columns[-1])

#The leaderboard during the training stage is based on traffic from January, 1st, 2017 up until March 1st, 2017.
# Out:
# 2015-07-01
# 2016-12-31

# %%
#The second stage will use training data up until September 1st, 2017.
train_2 = pd.read_csv('train_2.csv')
print(train_2.columns[1])
print(train_2.columns[-1])

#The final ranking of the competition will be based on predictions of daily views between September 13th, 2017
#and November 13th, 2017 for each article in the dataset.
# Out:
# 2015-07-01
# 2017-09-10

# %%
#For each time series, you are provided the name of the article as well as the type of traffic that this time
#series represent (all, mobile, desktop, spider).

#Unfortunately, the data source for this dataset does not distinguish between traffic values of zero and
#missing values. A missing value may mean the traffic was zero or that the data is not available for that day.
train_1.sample(8)
# Out:
#                                                      Page  2015-07-01  \
# 44711   File:Macrolepiota_procera_2013_G1.jpg_commons....         NaN
# 61227         元氣少女緣結神_zh.wikipedia.org_desktop_all-agents       315.0
# 98989   Кирк_Дуглас_ru.wikipedia.org_all-access_all-ag...       506.0
# 143819        Dinámica_es.wikipedia.org_all-access_spider         4.0
# 18101      Марафон_ru.wikipedia.org_mobile-web_all-agents       168.0
# 61502            个人电脑_zh.wikipedia.org_desktop_all-agents        53.0
# 111203  Hillary_House_and_Koffler_Museum_of_Medicine_e...         NaN
# 7998    Baccalauréat_en_France_fr.wikipedia.org_deskto...       438.0
#
#         2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  \
# 44711          NaN         NaN         NaN         NaN         NaN
# 61227        253.0       318.0       342.0       375.0       389.0
# 98989        318.0       301.0       392.0      2217.0       983.0
# ...

# %%
train_1.columns[1:]
# Out:
# Index(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04', '2015-07-05',
#        '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10',
#        ...
#        '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25', '2016-12-26',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2016-12-31'],
#       dtype='object', length=550)
